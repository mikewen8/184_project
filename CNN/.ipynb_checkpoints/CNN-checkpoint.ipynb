# %%
# !pip install 'tensorflow[and-cuda]'
# Out:
# Requirement already satisfied: tensorflow[and-cuda] in /home/michael/ml/lib/python3.12/site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: packaging in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.32.5)
# Requirement already satisfied: setuptools in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.4.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (0.5.4)
# Requirement already satisfied: nvidia-cublas-cu12<13.0,>=12.5.3.2 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12<13.0,>=12.5.82 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12<13.0,>=12.5.82 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.9.86)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12<13.0,>=12.5.82 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12<13.0,>=12.5.82 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.3.0.75 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12<12.0,>=11.2.3.61 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12<11.0,>=10.3.6.82 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12<12.0,>=11.6.3.83 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12<13.0,>=12.5.1.3 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.5.8.93)
# Requirement already satisfied: nvidia-nccl-cu12<3.0,>=2.27.7 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (2.29.7)
# Requirement already satisfied: nvidia-nvjitlink-cu12<13.0,>=12.5.82 in /home/michael/ml/lib/python3.12/site-packages (from tensorflow[and-cuda]) (12.8.93)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/michael/ml/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow[and-cuda]) (0.46.3)
# Requirement already satisfied: rich in /home/michael/ml/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[and-cuda]) (14.3.3)
# Requirement already satisfied: namex in /home/michael/ml/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[and-cuda]) (0.1.0)
# Requirement already satisfied: optree in /home/michael/ml/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow[and-cuda]) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/michael/ml/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/michael/ml/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michael/ml/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michael/ml/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/michael/ml/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow[and-cuda]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/michael/ml/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow[and-cuda]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/michael/ml/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow[and-cuda]) (0.1.2)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# set the hyper parameters
data_dir = "Rice_Image_Dataset"
img_height = 224
img_width = 224
batch_size = 32
seed = 123
# documentation on tensorflow website
train_ds  = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,# trainign percentatge
    subset="training",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='grayscale'
)
val_ds  = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,     # same split
    subset="validation",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='grayscale'
)

class_names = train_ds.class_names
print(class_names)

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 31600 files belonging to 3 classes.
# Using 25280 files for training.
# Found 31600 files belonging to 3 classes.
# Using 6320 files for validation.
# ['Arborio', 'Basmati', 'Ipsala']

# %%
num_classes=len(class_names)
model = Sequential([
    #each pixel will be equal to the input layer adn 
    layers.Input(shape=(224, 224, 1)),
    layers.Rescaling(1./255),
    layers.Conv2D(16, 1, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 1, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 1, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 16)   │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 32)   │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 64)     │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,422,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,425,731 (24.51 MB)
#  Trainable params: 6,425,731 (24.51 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 60s 75ms/step - accuracy: 0.9917 - loss: 0.0236 - val_accuracy: 0.9998 - val_loss: 0.0019
# Epoch 2/10
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 60s 75ms/step - accuracy: 0.9983 - loss: 0.0060 - val_accuracy: 0.9991 - val_loss: 0.0032
# Epoch 3/10
# 790/790 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.9981 - loss: 0.0063 - val_accuracy: 0.9937 - val_loss: 0.0231
# Epoch 4/10
# 206/790 ━━━━━━━━━━━━━━━━━━━━ 44s 76ms/step - accuracy: 0.9981 - loss: 0.0051

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
