# %%
#!pip install tensorflow[and-cuda]
#!pip install matplotlib
#!pip install tensorflow

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# absl-py                   2.4.0
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# astunparse                1.6.3
# async-lru                 2.2.0
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.5
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# flatbuffers               25.12.19
# fonttools                 4.62.1
# fqdn                      1.5.1
# gast                      0.7.0
# google-pasta              0.2.0
# grpcio                    1.78.0
# h11                       0.16.0
# h5py                      3.14.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# ipykernel                 7.2.0
# ipython                   9.11.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.13.0
# jsonpointer               3.0.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter_client            8.8.0
# jupyter-console           6.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.6
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# keras                     3.13.2
# kiwisolver                1.5.0
# lark                      1.3.1
# libclang                  18.1.1
# markdown-it-py            4.0.0
# MarkupSafe                3.0.3
# matplotlib                3.10.8
# matplotlib-inline         0.2.1
# mdurl                     0.1.2
# mistune                   3.2.0
# ml_dtypes                 0.5.4
# namex                     0.1.0
# nbclient                  0.10.4
# nbconvert                 7.17.0
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.5.5
# notebook_shim             0.2.4
# numpy                     2.4.3
# nvidia-cublas-cu12        12.9.1.4
# nvidia-cuda-cupti-cu12    12.9.79
# nvidia-cuda-nvcc-cu12     12.9.86
# nvidia-cuda-nvrtc-cu12    12.9.86
# nvidia-cuda-runtime-cu12  12.9.79
# nvidia-cudnn-cu12         9.20.0.48
# nvidia-cufft-cu12         11.4.1.4
# nvidia-curand-cu12        10.3.10.19
# nvidia-cusolver-cu12      11.7.5.82
# nvidia-cusparse-cu12      12.5.10.65
# nvidia-nccl-cu12          2.29.7
# nvidia-nvjitlink-cu12     12.9.86
# opt_einsum                3.4.0
# optree                    0.19.0
# packaging                 26.0
# pandocfilters             1.5.1
# parso                     0.8.6
# pexpect                   4.9.0
# pillow                    12.1.1
# pip                       26.0.1
# platformdirs              4.9.4
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# protobuf                  7.34.0
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 3.0
# Pygments                  2.19.2
# pyparsing                 3.3.2
# python-dateutil           2.9.0.post0
# python-json-logger        4.0.0
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rich                      14.3.3
# rpds-py                   0.30.0
# Send2Trash                2.1.0
# setuptools                82.0.1
# six                       1.17.0
# soupsieve                 2.8.3
# stack-data                0.6.3
# tensorflow                2.21.0
# termcolor                 3.3.0
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.5.5
# traitlets                 5.14.3
# typing_extensions         4.15.0
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   2.6.3
# wcwidth                   0.6.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# wheel                     0.46.3
# widgetsnbextension        4.0.15
# wrapt                     2.1.2

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print("GPU detected:", gpus)
    
    # Optional: prevent TensorFlow from allocating all VRAM
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

else:
    print("No GPU detected. Running on CPU.")
# Out:
# TensorFlow version: 2.21.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# set the hyper parameters
data_dir = "Rice_Image_Dataset"
img_height = 224
img_width = 224
batch_size = 64
seed = 123
# documentation on tensorflow website
train_ds  = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,# trainign percentatge
    subset="training",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='grayscale'
)
val_ds  = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,     # same split
    subset="validation",
    seed=seed,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='grayscale'
)

class_names = train_ds.class_names
print(class_names)

plt.figure(figsize=(10, 10))

for images, labels in train_ds.take(1):
    print("Batch shape:", images.shape)          # shows batch dimensions
    print("Single image shape:", images[0].shape) # shows one image size
    
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"), cmap="gray")
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# Found 75000 files belonging to 5 classes.
# Using 60000 files for training.
# I0000 00:00:1773488658.065006  158250 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13551 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9
# Found 75000 files belonging to 5 classes.
# Using 15000 files for validation.
# ['Arborio', 'Basmati', 'Ipsala', 'Jasmine', 'Karacadag']
# Batch shape: (64, 224, 224, 1)
# Single image shape: (224, 224, 1)

# %%
num_classes=len(class_names)
n_filters=1
model = Sequential([
    #each pixel will be equal to the input layer adn 
    layers.Input(batch_shape=(batch_size, img_height, img_width, 1)),
    layers.Rescaling(1./255),
    #convution 16x6 
    # number of filters 1x1 size
    layers.Conv2D(16, 4, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 4, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 4, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])

# %%
model.compile(optimizer='SGD',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# maybe add ADAM optimization pattern here

# %%
model.summary()
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (64, 224, 224, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (64, 224, 224, 16)     │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (64, 112, 112, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (64, 112, 112, 32)     │         8,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (64, 56, 56, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (64, 56, 56, 64)       │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (64, 28, 28, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (64, 50176)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (64, 128)              │     6,422,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (64, 5)                │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,464,629 (24.66 MB)
#  Trainable params: 6,464,629 (24.66 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# I0000 00:00:1773488666.820523  158373 service.cc:153] XLA service 0x7da76002f580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1773488666.820554  158373 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9 (Driver: 13.0.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.20.0)
# I0000 00:00:1773488666.850161  158373 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1773488666.919212  158373 cuda_dnn.cc:461] Loaded cuDNN version 92000
# I0000 00:00:1773488666.927356  158373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_866__.37
#   3/938 ━━━━━━━━━━━━━━━━━━━━ 58s 62ms/step - accuracy: 0.0998 - loss: 1.6122
# I0000 00:00:1773488669.820262  158373 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 919/938 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7441 - loss: 0.6383
# I0000 00:00:1773488697.916894  158373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_866__.37
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 39ms/step - accuracy: 0.8882 - loss: 0.2993 - val_accuracy: 0.9546 - val_loss: 0.1257
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9638 - loss: 0.1070 - val_accuracy: 0.9700 - val_loss: 0.0903
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 35ms/step - accuracy: 0.9700 - loss: 0.0871 - val_accuracy: 0.9721 - val_loss: 0.0801
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 32s 34ms/step - accuracy: 0.9718 - loss: 0.0808 - val_accuracy: 0.9747 - val_loss: 0.0749
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 29s 30ms/step - accuracy: 0.9732 - loss: 0.0763 - val_accuracy: 0.9644 - val_loss: 0.1042
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.9745 - loss: 0.0729 - val_accuracy: 0.9741 - val_loss: 0.0761
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.9753 - loss: 0.0704 - val_accuracy: 0.9731 - val_loss: 0.0766
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9764 - loss: 0.0681 - val_accuracy: 0.9785 - val_loss: 0.0655
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9770 - loss: 0.0655 - val_accuracy: 0.9781 - val_loss: 0.0649
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 32ms/step - accuracy: 0.9783 - loss: 0.0634 - val_accuracy: 0.9680 - val_loss: 0.0909

# %% [markdown]
# # Math takeaways
# $
# \
# \text{Number of batches per epoch} = \frac{60000 \text{ training images}}{64 \text{ batch size}} \approx 938 \text{ batches per epoch}
# \
# $

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save("rice_classifier.keras")
